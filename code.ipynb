# %%
import pandas as pd

customers_df = pd.read_csv("customers.csv")
noncustomers_df = pd.read_csv("noncustomers.csv")
usage_actions_df = pd.read_csv("usage_actions.csv")

print("customers:", customers_df.shape)
print("noncustomers:", noncustomers_df.shape)
print("usage_actions:", usage_actions_df.shape)

customers_df.head()
